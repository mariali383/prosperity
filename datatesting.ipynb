# %%
### READ THE DATA
import pandas as pd
import numpy as np
from pathlib import Path

root = Path("round-1-island-data-bottle")
prices1 = pd.read_csv(root / "prices_round_1_day_-1.csv", sep=";")
prices2 = pd.read_csv(root / "prices_round_1_day_-2.csv", sep=";")
prices3 = pd.read_csv(root / "prices_round_1_day_0.csv", sep=";")

trades1 = pd.read_csv(root / "trades_round_1_day_-1.csv", sep=";")
trades2 = pd.read_csv(root / "trades_round_1_day_-2.csv", sep=";")
trades3 = pd.read_csv(root / "trades_round_1_day_0.csv", sep=";")

# %%
trades1
# Out:
#       timestamp  buyer  seller            symbol   currency    price  quantity
# 0             0    NaN     NaN              KELP  SEASHELLS   2029.0        13
# 1             0    NaN     NaN              KELP  SEASHELLS   2029.0         1
# 2             0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  10004.0         1
# 3             0    NaN     NaN         SQUID_INK  SEASHELLS   2006.0        13
# 4             0    NaN     NaN         SQUID_INK  SEASHELLS   2006.0         1
# ...         ...    ...     ...               ...        ...      ...       ...
# 8301     999200    NaN     NaN         SQUID_INK  SEASHELLS   1970.0         1
# 8302     999400    NaN     NaN         SQUID_INK  SEASHELLS   1971.0         1
# 8303     999500    NaN     NaN              KELP  SEASHELLS   2030.0         2
# 8304     999500    NaN     NaN         SQUID_INK  SEASHELLS   1972.0         2
# 8305     999600    NaN     NaN  RAINFOREST_RESIN  SEASHELLS   9998.0         1
#
# [8306 rows x 7 columns]

# %% [markdown]
# # Concatenating the max_timestamps together

# %%
prices1
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -1          0         SQUID_INK         2005             1
# 1       -1          0  RAINFOREST_RESIN        10002             1
# 2       -1          0              KELP         2028             1
# 3       -1        100              KELP         2025            24
# 4       -1        100  RAINFOREST_RESIN         9996             2
# ...    ...        ...               ...          ...           ...
# 29995   -1     999800              KELP         2028            20
# 29996   -1     999800         SQUID_INK         1972            20
# 29997   -1     999900         SQUID_INK         1971            31
# 29998   -1     999900              KELP         2028            31
# 29999   -1     999900  RAINFOREST_RESIN         9996             2
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0           2002.0          31.0          NaN           NaN         2006
# ...

# %%
prices2
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0  RAINFOREST_RESIN         9996             1
# 1       -2          0              KELP         1998            26
# 2       -2          0         SQUID_INK         1998            26
# 3       -2        100         SQUID_INK         1999             5
# 4       -2        100  RAINFOREST_RESIN        10000             5
# ...    ...        ...               ...          ...           ...
# 29995   -2     999800  RAINFOREST_RESIN         9996             1
# 29996   -2     999800              KELP         2026            26
# 29997   -2     999900  RAINFOREST_RESIN         9996             2
# 29998   -2     999900              KELP         2027             4
# 29999   -2     999900         SQUID_INK         2003             4
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0           9995.0          25.0          NaN           NaN        10004
# ...

# %%
max_timestamp = prices2['timestamp'].max()

# Step 2: Shift the timestamps in prices1 so they continue after prices2
# Assume each day spans up to timestamp = 999900, so we shift by 1,000,000
# (or use max_timestamp + 100 to be exact if you want to generalize)
prices1_shifted = prices1.copy()
prices1_shifted['timestamp'] += (max_timestamp + 100)  # or 1000000

# Optional: If you want to reset the 'day' column too, to keep things clean
prices1_shifted['day'] = prices1_shifted['day'] + 1  # -1 becomes 0

# Step 3: Concatenate the dataframes
test_prices = pd.concat([prices2, prices1_shifted], ignore_index=True)

# Step 4 (optional): Sort by timestamp and product
test_prices = test_prices.sort_values(by=['timestamp', 'product']).reset_index(drop=True)

test_prices
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0              KELP         1998            26
# 1       -2          0  RAINFOREST_RESIN         9996             1
# 2       -2          0         SQUID_INK         1998            26
# 3       -2        100              KELP         2000             5
# 4       -2        100  RAINFOREST_RESIN        10000             5
# ...    ...        ...               ...          ...           ...
# 59995    0    1999800  RAINFOREST_RESIN         9995            20
# 59996    0    1999800         SQUID_INK         1972            20
# 59997    0    1999900              KELP         2028            31
# 59998    0    1999900  RAINFOREST_RESIN         9996             2
# 59999    0    1999900         SQUID_INK         1971            31
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0              NaN           NaN          NaN           NaN         2002
# ...

# %%
# Step 1: Pivot the dataframe on timestamp and day, with product as column level
flattened = test_prices.pivot(index=["timestamp", "day"], columns="product")

# Step 2: Flatten the multi-level column names
flattened.columns = [f"{product.lower()}_{col}" for col, product in flattened.columns]

# Step 3: Reset index to make it a flat dataframe again
flattened = flattened.reset_index()

test_prices = flattened

# %%
trades1
# Out:
#       timestamp  buyer  seller            symbol   currency    price  quantity
# 0             0    NaN     NaN              KELP  SEASHELLS   2029.0        13
# 1             0    NaN     NaN              KELP  SEASHELLS   2029.0         1
# 2             0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  10004.0         1
# 3             0    NaN     NaN         SQUID_INK  SEASHELLS   2006.0        13
# 4             0    NaN     NaN         SQUID_INK  SEASHELLS   2006.0         1
# ...         ...    ...     ...               ...        ...      ...       ...
# 8301     999200    NaN     NaN         SQUID_INK  SEASHELLS   1970.0         1
# 8302     999400    NaN     NaN         SQUID_INK  SEASHELLS   1971.0         1
# 8303     999500    NaN     NaN              KELP  SEASHELLS   2030.0         2
# 8304     999500    NaN     NaN         SQUID_INK  SEASHELLS   1972.0         2
# 8305     999600    NaN     NaN  RAINFOREST_RESIN  SEASHELLS   9998.0         1
#
# [8306 rows x 7 columns]

# %%
max_timestamp = trades2['timestamp'].max()

# Step 2: Shift the timestamps in prices1 so they continue after prices2
# Assume each day spans up to timestamp = 999900, so we shift by 1,000,000
# (or use max_timestamp + 100 to be exact if you want to generalize)
trades1_shifted = trades1.copy()
trades1_shifted['timestamp'] += (1000000)  # or 1000000

# Step 3: Concatenate the dataframes
test_trades = pd.concat([trades2, trades1_shifted], ignore_index=True)

# Step 4 (optional): Sort by timestamp and product
test_trades = test_trades.sort_values(by=['timestamp', 'symbol']).reset_index(drop=True)

test_trades
# Out:
#        timestamp  buyer  seller            symbol   currency   price  quantity
# 0              0    NaN     NaN              KELP  SEASHELLS  2002.0         1
# 1              0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 2              0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 3              0    NaN     NaN         SQUID_INK  SEASHELLS  2002.0         1
# 4            100    NaN     NaN              KELP  SEASHELLS  2002.0         6
# ...          ...    ...     ...               ...        ...     ...       ...
# 16699    1999200    NaN     NaN         SQUID_INK  SEASHELLS  1970.0         1
# 16700    1999400    NaN     NaN         SQUID_INK  SEASHELLS  1971.0         1
# 16701    1999500    NaN     NaN              KELP  SEASHELLS  2030.0         2
# 16702    1999500    NaN     NaN         SQUID_INK  SEASHELLS  1972.0         2
# 16703    1999600    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9998.0         1
#
# ...

# %%
# Step 1: Compute price * quantity and keep total volume
test_trades['total_value'] = test_trades['price'] * test_trades['quantity']

# Step 2: Group by timestamp and symbol to sum value and volume
aggregated = (
    test_trades
    .groupby(['timestamp', 'symbol'])
    .agg(total_value=('total_value', 'sum'), total_volume=('quantity', 'sum'))
    .reset_index()
)

# Step 3: Pivot to wide format for each symbol
values_pivot = aggregated.pivot(index='timestamp', columns='symbol', values='total_value').rename(
    columns={
        'KELP': 'kelp_value',
        'RAINFOREST_RESIN': 'rainforest_resin_value',
        'SQUID_INK': 'squid_ink_value'
    }
)

volumes_pivot = aggregated.pivot(index='timestamp', columns='symbol', values='total_volume').rename(
    columns={
        'KELP': 'kelp_volume',
        'RAINFOREST_RESIN': 'rainforest_resin_volume',
        'SQUID_INK': 'squid_ink_volume'
    }
)

# Step 4: Merge with full timestamp range
full_timestamps = pd.DataFrame({'timestamp': np.arange(test_trades['timestamp'].min(), test_trades['timestamp'].max() + 100, 100)})
combined = full_timestamps.merge(values_pivot, on='timestamp', how='left').merge(volumes_pivot, on='timestamp', how='left')

rolling_vwap_df = combined[['timestamp']].copy()



# Start with just the timestamp column
rolling_vwap_df = combined[['timestamp']].copy()

# Compute rolling VWAPs
rolling_windows = [2, 3, 5, 7, 10, 20]
for rolling_window in rolling_windows:
    for symbol in ['kelp', 'rainforest_resin', 'squid_ink']:
        value_col = f'{symbol}_value'
        volume_col = f'{symbol}_volume'
        vwap_col = f'{symbol}_vwap_rolling_{rolling_window}'

        rolling_vwap_df[vwap_col] = (
            combined[value_col].rolling(window=rolling_window, min_periods=1).sum() /
            combined[volume_col].rolling(window=rolling_window, min_periods=1).sum()
        )


rolling_vwap_df.tail()
# Out:
#        timestamp  kelp_vwap_rolling_2  rainforest_resin_vwap_rolling_2  \
# 19992    1999200          2029.071429                              NaN
# 19993    1999300          2029.111111                              NaN
# 19994    1999400                  NaN                              NaN
# 19995    1999500          2030.000000                              NaN
# 19996    1999600          2030.000000                           9998.0
#
#        squid_ink_vwap_rolling_2  kelp_vwap_rolling_3  \
# 19992               1970.142857          2029.071429
# 19993               1970.222222          2029.071429
# 19994               1971.000000          2029.111111
# 19995               1971.666667          2030.000000
# 19996               1972.000000          2030.000000
#
#        rainforest_resin_vwap_rolling_3  squid_ink_vwap_rolling_3  \
# 19992                              NaN               1970.142857
# 19993                              NaN               1970.142857
# ...

# %%
vwap_cols = [col for col in test_prices.columns if 'vwap_rolling' in col]
test_prices = test_prices.drop(columns=vwap_cols)

# Now merge again
test_prices = test_prices.merge(rolling_vwap_df, on='timestamp', how='left')

# %% [markdown]
# To improve the readability of this, flatten the dataframe down so features can be made more easily

# %%
test_prices.columns
# Out:
# Index(['timestamp', 'day', 'kelp_bid_price_1', 'rainforest_resin_bid_price_1',
#        'squid_ink_bid_price_1', 'kelp_bid_volume_1',
#        'rainforest_resin_bid_volume_1', 'squid_ink_bid_volume_1',
#        'kelp_bid_price_2', 'rainforest_resin_bid_price_2',
#        'squid_ink_bid_price_2', 'kelp_bid_volume_2',
#        'rainforest_resin_bid_volume_2', 'squid_ink_bid_volume_2',
#        'kelp_bid_price_3', 'rainforest_resin_bid_price_3',
#        'squid_ink_bid_price_3', 'kelp_bid_volume_3',
#        'rainforest_resin_bid_volume_3', 'squid_ink_bid_volume_3',
#        'kelp_ask_price_1', 'rainforest_resin_ask_price_1',
#        'squid_ink_ask_price_1', 'kelp_ask_volume_1',
#        'rainforest_resin_ask_volume_1', 'squid_ink_ask_volume_1',
#        'kelp_ask_price_2', 'rainforest_resin_ask_price_2',
#        'squid_ink_ask_price_2', 'kelp_ask_volume_2',
#        'rainforest_resin_ask_volume_2', 'squid_ink_ask_volume_2',
# ...

# %%
# Make sure all the VWAP columns are already merged into test_prices
# Now calculate the difference between VWAP and mid_price for each rolling window

symbols = ['squid_ink', 'kelp', 'rainforest_resin']
rolling_windows = [2, 3, 5, 7, 10, 20]

for symbol in symbols:
    mid_col = f"{symbol}_mid_price"
    for window in rolling_windows:
        vwap_col = f"{symbol}_vwap_rolling_{window}"
        diff_col = f"{symbol}_vwap_{window}_diff"
        test_prices[diff_col] = test_prices[vwap_col] - test_prices[mid_col]

# %%
test_prices.columns
# Out:
# Index(['timestamp', 'day', 'kelp_bid_price_1', 'rainforest_resin_bid_price_1',
#        'squid_ink_bid_price_1', 'kelp_bid_volume_1',
#        'rainforest_resin_bid_volume_1', 'squid_ink_bid_volume_1',
#        'kelp_bid_price_2', 'rainforest_resin_bid_price_2',
#        'squid_ink_bid_price_2', 'kelp_bid_volume_2',
#        'rainforest_resin_bid_volume_2', 'squid_ink_bid_volume_2',
#        'kelp_bid_price_3', 'rainforest_resin_bid_price_3',
#        'squid_ink_bid_price_3', 'kelp_bid_volume_3',
#        'rainforest_resin_bid_volume_3', 'squid_ink_bid_volume_3',
#        'kelp_ask_price_1', 'rainforest_resin_ask_price_1',
#        'squid_ink_ask_price_1', 'kelp_ask_volume_1',
#        'rainforest_resin_ask_volume_1', 'squid_ink_ask_volume_1',
#        'kelp_ask_price_2', 'rainforest_resin_ask_price_2',
#        'squid_ink_ask_price_2', 'kelp_ask_volume_2',
#        'rainforest_resin_ask_volume_2', 'squid_ink_ask_volume_2',
# ...

# %% [markdown]
# # Creating Target Features
# - Aim to look forward a given amount
# - Aim to capture this first via absolute change
# - Lookback periods potentially ranging from 1-10 timestamps ahead

# %%
lookahead_periods = [1, 2, 3, 5, 7, 10]
target_cols = ['kelp_mid_price', 'rainforest_resin_mid_price', 'squid_ink_mid_price']

for col in target_cols:
    for period in lookahead_periods:
        new_col = f"{col}_fwd_diff_{period}"
        test_prices[new_col] = test_prices[col].shift(-period) - test_prices[col]

# %%
test_prices
# Out:
#        timestamp  day  kelp_bid_price_1  rainforest_resin_bid_price_1  \
# 0              0   -2              1998                          9996
# 1            100   -2              2000                         10000
# 2            200   -2              1999                          9996
# 3            300   -2              1999                          9996
# 4            400   -2              1999                          9995
# ...          ...  ...               ...                           ...
# 19995    1999500    0              2029                         10000
# 19996    1999600    0              2029                         10000
# 19997    1999700    0              2028                          9995
# 19998    1999800    0              2028                          9995
# 19999    1999900    0              2028                          9996
#
#        squid_ink_bid_price_1  kelp_bid_volume_1  \
# 0                       1998                 26
# ...

# %%
import matplotlib.pyplot as plt
def plot_column(column_name):
    plt.figure(figsize=(12, 4))
    plt.plot(test_prices[column_name])
    plt.title(column_name)
    plt.xlabel('Timestep')
    plt.ylabel('Price Difference')
    plt.grid(True)
    plt.show()
    
plot_column('squid_ink_mid_price_fwd_diff_3')

# %% [markdown]
# # Creating Features
# - I will demonstrate using an exponential moving average simple momentum strategy
# - When you create target features, please create and edit in another cell to help merge requests

# %%
test_prices['kelp_mid_price_diff'] = test_prices['kelp_mid_price'] - test_prices['kelp_mid_price'].shift(1)
test_prices['rainforest_resin_mid_price_diff'] = test_prices['rainforest_resin_mid_price'] - test_prices['rainforest_resin_mid_price'].shift(1)
test_prices['squid_ink_mid_price_diff'] = test_prices['squid_ink_mid_price'] - test_prices['squid_ink_mid_price'].shift(1)

# %%
test_prices
# Out:
#        timestamp  day  kelp_bid_price_1  rainforest_resin_bid_price_1  \
# 0              0   -2              1998                          9996
# 1            100   -2              2000                         10000
# 2            200   -2              1999                          9996
# 3            300   -2              1999                          9996
# 4            400   -2              1999                          9995
# ...          ...  ...               ...                           ...
# 19995    1999500    0              2029                         10000
# 19996    1999600    0              2029                         10000
# 19997    1999700    0              2028                          9995
# 19998    1999800    0              2028                          9995
# 19999    1999900    0              2028                          9996
#
#        squid_ink_bid_price_1  kelp_bid_volume_1  \
# 0                       1998                 26
# ...

# %%
lookback_periods = [3, 5, 7, 10, 15, 20, 30]
columns_to_calculate_ema = ['kelp_mid_price_diff', 'rainforest_resin_mid_price_diff', 'squid_ink_mid_price_diff']

for col in columns_to_calculate_ema:
    for period in lookback_periods:
        ema_col_name = f'{col}_ema_{period}'
        test_prices[ema_col_name] = test_prices[col].ewm(span=period, adjust=False).mean()

# %%
test_prices.columns
# Out:
# Index(['timestamp', 'day', 'kelp_bid_price_1', 'rainforest_resin_bid_price_1',
#        'squid_ink_bid_price_1', 'kelp_bid_volume_1',
#        'rainforest_resin_bid_volume_1', 'squid_ink_bid_volume_1',
#        'kelp_bid_price_2', 'rainforest_resin_bid_price_2',
#        ...
#        'rainforest_resin_mid_price_diff_ema_15',
#        'rainforest_resin_mid_price_diff_ema_20',
#        'rainforest_resin_mid_price_diff_ema_30',
#        'squid_ink_mid_price_diff_ema_3', 'squid_ink_mid_price_diff_ema_5',
#        'squid_ink_mid_price_diff_ema_7', 'squid_ink_mid_price_diff_ema_10',
#        'squid_ink_mid_price_diff_ema_15', 'squid_ink_mid_price_diff_ema_20',
#        'squid_ink_mid_price_diff_ema_30'],
#       dtype='object', length=122)

# %% [markdown]
# ### Buying pressure and selling pressure
# Attempt to model buying and selling pressure

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def linear_regression_plot(df, feature_col, target_col):
    """
    Performs linear regression to predict target_col using feature_col and plots the result.
    Also prints the correlation coefficient.
    """
    # Drop rows where either feature or target column contains NaN values
    df_clean = df.dropna(subset=[feature_col, target_col])
    
    # Prepare the data
    X = df_clean[[feature_col]].values  # Feature (2D for sklearn)
    y = df_clean[target_col].values     # Target (1D)

    # Compute correlation coefficient
    corr = np.corrcoef(df_clean[feature_col], df_clean[target_col])[0, 1]
    
    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)
    
    # Get slope and intercept
    gradient = model.coef_[0]
    intercept = model.intercept_
    
    # Predict values
    y_pred = model.predict(X)
    
    # Plotting
    plt.figure(figsize=(6, 6))
    plt.scatter(df_clean[feature_col], df_clean[target_col], color='blue', label='Data points')
    plt.plot(df_clean[feature_col], y_pred, color='red', label=f'Regression Line (y = {gradient:.2f}x + {intercept:.2f})')
    
    plt.title(f'Linear Regression: {target_col} vs {feature_col}')
    plt.xlabel(feature_col)
    plt.ylabel(target_col)
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Print results
    print(f"Gradient (Slope): {gradient:.2f}")
    print(f"Intercept: {intercept:.2f}")
    print(f"Correlation Coefficient: {corr:.4f}")

# Example usage:
linear_regression_plot(test_prices, 'squid_ink_mid_price_diff_ema_20', 'squid_ink_mid_price_fwd_diff_3')

linear_regression_plot(test_prices, 'kelp_vwap_2_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'kelp_vwap_3_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'kelp_vwap_5_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'kelp_vwap_7_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'kelp_vwap_10_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'kelp_vwap_20_diff', 'kelp_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_2_diff', 'squid_ink_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_3_diff', 'squid_ink_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_5_diff', 'squid_ink_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_7_diff', 'squid_ink_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_10_diff', 'squid_ink_mid_price_fwd_diff_1')
linear_regression_plot(test_prices, 'squid_ink_vwap_20_diff', 'squid_ink_mid_price_fwd_diff_1')
# Out:
# Gradient (Slope): -0.48
# Intercept: -0.00
# Correlation Coefficient: -0.0583
# Gradient (Slope): 0.14
# Intercept: 0.07
# Correlation Coefficient: 0.2076
# Gradient (Slope): 0.15
# Intercept: 0.07
# Correlation Coefficient: 0.2353
# Gradient (Slope): 0.17
# Intercept: 0.07
# Correlation Coefficient: 0.2561
# Gradient (Slope): 0.18
# Intercept: 0.08
# Correlation Coefficient: 0.2716
# Gradient (Slope): 0.19
# Intercept: 0.08
# Correlation Coefficient: 0.2894
# Gradient (Slope): 0.23
# Intercept: 0.09
# Correlation Coefficient: 0.3186
# Gradient (Slope): 0.03
# Intercept: 0.02
# Correlation Coefficient: 0.0295
# Gradient (Slope): 0.04
# Intercept: 0.02
# Correlation Coefficient: 0.0449
# Gradient (Slope): 0.01
# Intercept: 0.01
# Correlation Coefficient: 0.0182
# Gradient (Slope): 0.03
# Intercept: 0.01
# Correlation Coefficient: 0.0555
# Gradient (Slope): 0.04
# Intercept: 0.02
# Correlation Coefficient: 0.0731
# Gradient (Slope): 0.02
# Intercept: 0.01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def test_feature(df, feature_col, target_col):
    """
    Performs linear regression to predict target_col using feature_col and plots the result.
    Also prints the correlation coefficient.
    """
    # Drop rows where either feature or target column contains NaN values
    df_clean = df.dropna(subset=[feature_col, target_col])
    
    # Prepare the data
    X = df_clean[[feature_col]].values  # Feature (2D for sklearn)
    y = df_clean[target_col].values     # Target (1D)

    # Compute correlation coefficient
    corr = np.corrcoef(df_clean[feature_col], df_clean[target_col])[0, 1]
    
    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)
    
    # Get slope and intercept
    gradient = model.coef_[0]
    intercept = model.intercept_
    
    # Predict values
    y_pred = model.predict(X)
    
    # Print results
    print(f"Gradient (Slope): {gradient:.2f}")
    print(f"Intercept: {intercept:.2f}")
    print(f"Correlation Coefficient: {corr:.4f}")

# Example usage:
linear_regression_plot(test_prices, 'squid_ink_mid_price_diff_ema_3', 'squid_ink_mid_price_fwd_diff_1')
# Out:
# Gradient (Slope): -0.32
# Intercept: -0.00
# Correlation Coefficient: -0.1673

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
def model_param_calc(dataframe, feature_columns, target_column, lower_bound, upper_bound):
    """
    Train and evaluate a linear regression model with customizable features and target column.

    Parameters:
    dataframe (pd.DataFrame): Input DataFrame containing the features and target.
    feature_columns (list): List of column names to be used as features.
    target_column (str): Name of the column to be used as the target.

    Returns:
    dict: A dictionary containing the model, intercept, coefficients, R-squared, and mean squared error.

    """

    # Drop rows with NaN values in the selected features and target
    filtered_df = dataframe.dropna(subset=feature_columns + [target_column])

    # Extract features (X) and target (y)
    X = filtered_df[feature_columns].values  # 2D array
    y = filtered_df[target_column].values  # 1D array

    # Train the linear regression model
    model = LinearRegression()
    model.fit(X, y)

    # Make predictions
    predicted_y = model.predict(X)

    # Create a mask for rows to keep (outside the range)
    mask = (predicted_y < lower_bound) | (predicted_y > upper_bound)

    X_filtered = X[mask]
    y_filtered = y[mask]
    predicted_y_filtered = predicted_y[mask]

    # Evaluate the model
    r2 = r2_score(y_filtered, predicted_y_filtered)
    mse = mean_squared_error(y_filtered, predicted_y_filtered)

    totalScore = 0

    posTotal, negTotal = 0, 0
    posHits, negHits = 0, 0
    posHitRate, negHitRate = 0, 0
    for i in range(len(predicted_y_filtered)):
        
        # If predicted show strong signal, check whether signal valid or not
        if predicted_y_filtered[i] > upper_bound:
            posTotal += 1
            if y_filtered[i] > 0:
                posHits += 1
            totalScore += y_filtered[i]

        if predicted_y_filtered[i] < lower_bound:
            negTotal += 1
            if y_filtered[i] < 0:
                negHits += 1
            totalScore -= y_filtered[i]

    avgScore = totalScore/(posTotal + negTotal)

    if posTotal > 0 and negTotal > 0:
        posHitRate = posHits/posTotal*100
        negHitRate = negHits/negTotal*100   

    frequency = posTotal + negTotal

    # Return the results
    return {
        "model": model,
        "features": feature_columns,
        "intercept": model.intercept_,
        "coefficients": model.coef_,
        "r_squared": r2,
        "mean_squared_error": mse,
        "pos_hit_rate": posHitRate,
        "neg_hit_rate": negHitRate,
        "total_score": totalScore,
        "avg_score": avgScore,
        "frequency": frequency
    }

# %%
result = model_param_calc(test_prices, ["kelp_vwap_20_diff"], 'kelp_mid_price_fwd_diff_1', 3, 3)

print(result)
# Out:
# {'model': LinearRegression(), 'features': ['kelp_vwap_20_diff'], 'intercept': 0.0871780198427321, 'coefficients': array([0.22637228]), 'r_squared': 0.10151102919037402, 'mean_squared_error': 0.5528251635827627, 'pos_hit_rate': 50.0, 'neg_hit_rate': 30.54552747693542, 'total_score': -34.0, 'avg_score': -0.0017046024265516895, 'frequency': 19946}

# %%
test_prices.columns
# Out:
# Index(['timestamp', 'day', 'kelp_bid_price_1', 'rainforest_resin_bid_price_1',
#        'squid_ink_bid_price_1', 'kelp_bid_volume_1',
#        'rainforest_resin_bid_volume_1', 'squid_ink_bid_volume_1',
#        'kelp_bid_price_2', 'rainforest_resin_bid_price_2',
#        ...
#        'rainforest_resin_mid_price_diff_ema_15',
#        'rainforest_resin_mid_price_diff_ema_20',
#        'rainforest_resin_mid_price_diff_ema_30',
#        'squid_ink_mid_price_diff_ema_3', 'squid_ink_mid_price_diff_ema_5',
#        'squid_ink_mid_price_diff_ema_7', 'squid_ink_mid_price_diff_ema_10',
#        'squid_ink_mid_price_diff_ema_15', 'squid_ink_mid_price_diff_ema_20',
#        'squid_ink_mid_price_diff_ema_30'],
#       dtype='object', length=122)

# %%
feature_list = ['squid_ink_mid_price_diff_ema_3', 'squid_ink_mid_price_diff_ema_5',
       'squid_ink_mid_price_diff_ema_7', 'squid_ink_mid_price_diff_ema_10',
       'squid_ink_mid_price_diff_ema_15', 'squid_ink_mid_price_diff_ema_20',
       'squid_ink_mid_price_diff_ema_30', 'kelp_mid_price_diff_ema_5', 'kelp_mid_price_diff_ema_7',
       'kelp_mid_price_diff_ema_10', 'kelp_mid_price_diff_ema_15',
       'kelp_mid_price_diff_ema_20', 'kelp_mid_price_diff_ema_30']

targets = []
